# %% [markdown]
# <a href="https://colab.research.google.com/github/Nubiancodingdelight/ACS-Project-Repository-/blob/main/Download_Reference_Genomes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Created by: Lorrayya Williams
# Updated on: 3/19/2025

# %%
#mounts google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#this function unzips gzip files
import os
import gzip
import shutil

def unzip_files(zip_folder, extract_folder):
  if not os.path.exists(extract_folder):
      os.makedirs(extract_folder)

  for file in os.listdir(zip_folder):
      if file.endswith('.gz'):
          zip_path = os.path.join(zip_folder, file)
          extract_path = os.path.join(extract_folder, os.path.splitext(file)[0])

          with gzip.open(zip_path, 'rb') as f_in:
              with open(extract_path, 'wb') as f_out:
                  shutil.copyfileobj(f_in, f_out)
          print(f"Extracted: {file}")

# %% [markdown]
# Hg19 Reference Genome Download
#
# Reference
# https://www.gungorbudak.com/blog/2014/04/13/download-human-reference-genome-hg19/

# %%
#open pathway for hg19
# %cd /content/drive/MyDrive/ACS_Research/VISDB_Data/Human_Reference/hg19/compressed
# %ls
# Out:
# /content/drive/MyDrive/ACS_Research/VISDB_Data/Human_Reference/hg19/compressed
# chr10.fa.gz                  chr5.fa.gz                  chrUn_gl000223.fa.gz
# chr11.fa.gz                  chr6_apd_hap1.fa.gz         chrUn_gl000224.fa.gz
# chr11_gl000202_random.fa.gz  chr6_cox_hap2.fa.gz         chrUn_gl000225.fa.gz
# chr12.fa.gz                  chr6_dbb_hap3.fa.gz         chrUn_gl000226.fa.gz
# chr13.fa.gz                  chr6.fa.gz                  chrUn_gl000227.fa.gz
# chr14.fa.gz                  chr6_mann_hap4.fa.gz        chrUn_gl000228.fa.gz
# chr15.fa.gz                  chr6_mcf_hap5.fa.gz         chrUn_gl000229.fa.gz
# chr16.fa.gz                  chr6_qbl_hap6.fa.gz         chrUn_gl000230.fa.gz
# chr17_ctg5_hap1.fa.gz        chr6_ssto_hap7.fa.gz        chrUn_gl000231.fa.gz
# chr17.fa.gz                  chr7.fa.gz                  chrUn_gl000232.fa.gz
# chr17_gl000203_random.fa.gz  chr7_gl000195_random.fa.gz  chrUn_gl000233.fa.gz
# ...

# %%
 #download compressed reference files
 # !wget --timestamping 'ftp://hgdownload.cse.ucsc.edu/goldenPath/hg19/chromosomes/*'
# Out:
# --2025-03-20 00:37:59--  ftp://hgdownload.cse.ucsc.edu/goldenPath/hg19/chromosomes/*
#            => ‘.listing’
# Resolving hgdownload.cse.ucsc.edu (hgdownload.cse.ucsc.edu)... 128.114.119.163
# Connecting to hgdownload.cse.ucsc.edu (hgdownload.cse.ucsc.edu)|128.114.119.163|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /goldenPath/hg19/chromosomes ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
# .listing                [ <=>                ]   7.13K  --.-KB/s    in 0.03s
#
# 2025-03-20 00:38:00 (210 KB/s) - ‘.listing’ saved [7300]
#
# Removed ‘.listing’.
# --2025-03-20 00:38:00--  ftp://hgdownload.cse.ucsc.edu/goldenPath/hg19/chromosomes/chr10.fa.gz
#            => ‘chr10.fa.gz’
# ==> CWD not required.
# ==> PASV ... done.    ==> RETR chr10.fa.gz ... done.
# Length: 43026389 (41M)
#
# chr10.fa.gz         100%[===================>]  41.03M  22.0MB/s    in 1.9s
#
# ...

# %%
#unzip files
unzip_files('/content/drive/MyDrive/ACS_Research/VISDB_Data/Human_Reference/hg19/compressed', '/content/drive/MyDrive/ACS_Research/VISDB_Data/Human_Reference/hg19/uncompressed')
# Out:
# Extracted: chr17_ctg5_hap1.fa.gz
# Extracted: chrUn_gl000245.fa.gz
# Extracted: chrUn_gl000231.fa.gz
# Extracted: chr19_gl000208_random.fa.gz
# Extracted: chr17_gl000203_random.fa.gz
# Extracted: chr6_mann_hap4.fa.gz
# Extracted: chr19.fa.gz
# Extracted: chrUn_gl000220.fa.gz
# Extracted: chr22.fa.gz
# Extracted: chr11_gl000202_random.fa.gz
# Extracted: chrY.fa.gz
# Extracted: chr17_gl000204_random.fa.gz
# Extracted: chr9_gl000200_random.fa.gz
# Extracted: chrUn_gl000215.fa.gz
# Extracted: chr4_ctg9_hap1.fa.gz
# Extracted: chrUn_gl000240.fa.gz
# Extracted: chr6_cox_hap2.fa.gz
# Extracted: chr8_gl000197_random.fa.gz
# Extracted: chr3.fa.gz
# Extracted: chrUn_gl000224.fa.gz
# Extracted: chr5.fa.gz
# Extracted: chrUn_gl000227.fa.gz
# Extracted: chr11.fa.gz
# Extracted: chr19_gl000209_random.fa.gz
# Extracted: chrUn_gl000222.fa.gz
# Extracted: chr7_gl000195_random.fa.gz
# Extracted: chr7.fa.gz
# Extracted: chr10.fa.gz
# Extracted: chr2.fa.gz
# Extracted: chrUn_gl000233.fa.gz
# ...

# %% [markdown]
# Hg38 Reference Genome Download
#
# **Reference**
# https://www.gungorbudak.com/blog/2018/05/16/how-to-download-hg38-grch38-fasta-human-reference-genome/

# %%
#Open path for hg38
# %cd /content/drive/MyDrive/ACS_Research/VISDB_Data/Human_Reference/hg38/compressed
# Out:
# /content/drive/MyDrive/ACS_Research/VISDB_Data/Human_Reference/hg38/compressed

# %%
# !wget http://hgdownload.soe.ucsc.edu/goldenPath/hg38/bigZips/hg38.fa.gz
# Out:
# --2025-03-20 00:39:25--  http://hgdownload.soe.ucsc.edu/goldenPath/hg38/bigZips/hg38.fa.gz
# Resolving hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)... 128.114.119.163
# Connecting to hgdownload.soe.ucsc.edu (hgdownload.soe.ucsc.edu)|128.114.119.163|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 983659424 (938M) [application/x-gzip]
# Saving to: ‘hg38.fa.gz’
#
# hg38.fa.gz          100%[===================>] 938.09M  40.3MB/s    in 24s
#
# 2025-03-20 00:39:50 (39.2 MB/s) - ‘hg38.fa.gz’ saved [983659424/983659424]

# %%
#unzip files
unzip_files('/content/drive/MyDrive/ACS_Research/VISDB_Data/Human_Reference/hg38/compressed', '/content/drive/MyDrive/ACS_Research/VISDB_Data/Human_Reference/hg38/uncompressed')
# Out:
# Extracted: hg38.fa.gz
